# %%
import matplotlib.pyplot as plt

# %%
f = open("output.txt","r")
x =[]
for each in f:
    x.append(tuple((int(item)) for item in each.split(' ')))

# %%
for i in x:
    for j in i:
        coord.append((coord[j]))

# %%
f = open("output.txt","r")
x =[]
for each in f:
    x.append(tuple((int(item)) for item in each.split(' ')))

# %%
xs, ys = zip(*coord) #create lists of x and y values

plt.figure()
plt.plot(xs,ys) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-2769744ffbf0> in <module>
# ----> 1 xs, ys = zip(*coord) #create lists of x and y values
#       2
#       3 plt.figure()
#       4 plt.plot(xs,ys)
#       5 plt.show()
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
ind = 13
for i in range(6):
    coord.insert(ind,(-1,coord[ind-1][1]+1))
    ind = ind+1
    coord.insert(ind,(-2,coord[ind-1][1]+1))
    ind = ind+1
x = 0
y = ind
for i in range(6):
    x = x + 1
    coord.insert(ind,(2,coord[y-x][1]))
    ind = ind+1
    x = x + 1
    coord.insert(ind,(1,coord[y-x][1]))
    ind = ind+1

# %%
coord
xs, ys = zip(*coord) #create lists of x and y values

plt.figure()
plt.plot(xs,ys) 
plt.show()

# %%
with open('input1.txt', 'w') as fh:
    for i in range(len(coord)-1):
            fh.write(str((str(coord[i])[0]))+" "+str(((coord[i])[1])))

# %%
for i in x:
    for j in i:
        coord.append((coord[j]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-197-6fc0a6ceeafe> in <module>
# ----> 1 for i in x:
#       2     for j in i:
#       3         coord.append((coord[j]))
#
# TypeError: 'int' object is not iterable

# %%
xs, ys = zip(*coord) #create lists of x and y values

plt.figure()
plt.plot(xs,ys) 
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_csv("Book1.csv")

# %%
df
# Out:
#     NOV      TIME
# 0    10  0.000118
# 1    18  0.000405
# 2    26  0.001115
# 3    50  0.002903
# 4   102  0.009375
# 5   202  0.060748
# 6   502  0.334932
# 7  1002  2.057910

# %%
df.plot(x='NOV', y='TIME', kind='line')
# Out:
# <AxesSubplot:xlabel='NOV'>

# %%
f = open("input1.txt","w")

# %%
tup = (1,2)
for x in tup:
    print(x)
# Out:
# 1
# 2
